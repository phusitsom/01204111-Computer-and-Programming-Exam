# %%
import sympy, math

# %% [markdown]
# ## 11. What is the output of the following code fragment?

# %%
if 2%3 == 1 and 7/3 > 0:
    print('1st condition')
elif 2**3 == 3**2:
    print('2nd condition')
if False:
    print('3rd condition')  
else:
    print('No one.')
# Out:
# No one.

# %% [markdown]
# ## 12. What is the Python expression for calculating the following mathematical expression?

# %%
n, k = sympy.symbols('n k')
n * (k+1)**2 / 2
# Out:
# n*(k + 1)**2/2

# %%
n * (k+1)/2 * (k+1)/2
# Out:
# n*(k + 1)**2/4

# %%
n/2 * (k+1)**2 # Choice 2 Correct answer
# Out:
# n*(k + 1)**2/2

# %%
n * (k+1**2)/2
# Out:
# n*(k + 1)/2

# %%
(nk**2+2*nk+n)/2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-1bbf4a5d2be0> in <module>
# ----> 1 (nk**2+2*nk+n)/2
#
# NameError: name 'nk' is not defined

# %%
n/2*math.power(2,k+1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-e2b443e940d4> in <module>
# ----> 1 n/2*math.power(2,k+1)
#
# AttributeError: module 'math' has no attribute 'power'

# %% [markdown]
# ## 32. What is a statement to be filled in the blank **(A)** to produce the example output?

# %%
j = 32.5
print("00987654321")
print(f"{j:<6}")
print("00987654321")
# Out:
# 00987654321
# 32.5
# 00987654321

# %%
j = 32.5
print("0987654321")
print(f"{j:>6}")
print("0987654321")
# Out:
# 0987654321
#   32.5
# 0987654321

# %%
j = 32.5
print("0987654321")
print(f"(32.5:>6)")
print("0987654321")
# Out:
# 0987654321
# (32.5:>6)
# 0987654321

# %%
j = 32.5
print("0987654321")
print(f"{32:4}.5")
print("0987654321")
# Out:
# 0987654321
#   32.5
# 0987654321

# %% [markdown]
# ### Others

# %%
print(f"{32:.2f}.5")
print(f"{32:f}.5")
# Out:
# 32.00.5
# 32.000000.5

# %%
print(f"{32:e}.5")
# Out:
# 3.200000e+01.5

# %%
print(f"{32:9}.5")
print(f"{32:09}.5")
print(f"{32:0000000000000000009}.5")
# Out:
#        32.5
# 000000032.5
# 000000032.5

# %%
print(f"{32:<4}.5")
print(f"{32:>4}.5")
print(f"{32:<6}.5")
print(f"{32:>6}.5")
# Out:
# 32  .5
#   32.5
# 32    .5
#     32.5

# %%
print(f"{32:0<4}.5")
print(f"{32:0>6}.5")
# Out:
# 3200.5
# 000032.5

# %%
print(f"{32:^6}.5")
print(f"{32:^10}.5")
# Out:
#   32  .5
#     32    .5

# %% [markdown]
# ## 38. What is the output of the following code fragment?

# %%
def f(x):
    if (x >= 1):
        return "Hello"
    elif (x == 2):
        return "2"
    else:
        return 1
print(f(1)+f(2)*f(0))
# Out:
# HelloHello

# %% [markdown]
# ## 46. Which statement causes a syntax error?

# %%
f'"I am" an engineer.'
# Out:
# '"I am" an engineer.'

# %%
f'Pi is equal {3.14159>.2f}'
# Out:
#   File "<ipython-input-84-490c813ba140>", line 1
#     f'Pi is equal {3.14159>.2f}'
#                ^
# SyntaxError: f-string: invalid syntax

# %%
f"""I'm a good student."""
# Out:
# "I'm a good student."

# %%
'sin(45) is equal {2**0.5/2}'
# Out:
# 'sin(45) is equal {2**0.5/2}'
